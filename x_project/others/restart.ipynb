# %%
import pandas as pd
import numpy as np

ts_df = pd.read_csv('./datasets/data_TV.csv', encoding='latin1')
ts_df
# Out:
#      first_air_date origin_country original_language               name  \
# 0        2021-09-03             US                en  The D'Amelio Show
# 1        2008-01-20             US                en       Breaking Bad
# 2        2021-11-06             US                en             Arcane
# 3        2013-12-02             US                en     Rick and Morty
# 4        2022-04-14             US                en    The Kardashians
# ...             ...            ...               ...                ...
# 2612     2002-06-11             US                en      American Idol
# 2613     2000-07-05             US                en        Big Brother
# 2614     1997-03-31             GB                en        Teletubbies
# 2615     1985-02-19             GB                en         EastEnders
# 2616     2006-10-09             CA                fr             La Job
#
#       popularity  vote_average  vote_count  \
# 0         30.104           9.0        3071
# ...

# %%
# ts_df feature들의 정보 확인

ts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2617 entries, 0 to 2616
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   first_air_date     2611 non-null   object
#  1   origin_country     2617 non-null   object
#  2   original_language  2617 non-null   object
#  3   name               2617 non-null   object
#  4   popularity         2617 non-null   float64
#  5   vote_average       2617 non-null   float64
#  6   vote_count         2617 non-null   int64
#  7   overview           2552 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 163.7+ KB

# %%
# 필요 없는 feature 삭제

# ts_df.drop(columns=['overview'], inplace=True)

# %%
ts_df
# Out:
#      first_air_date origin_country original_language               name  \
# 0        2021-09-03             US                en  The D'Amelio Show
# 1        2008-01-20             US                en       Breaking Bad
# 2        2021-11-06             US                en             Arcane
# 3        2013-12-02             US                en     Rick and Morty
# 4        2022-04-14             US                en    The Kardashians
# ...             ...            ...               ...                ...
# 2612     2002-06-11             US                en      American Idol
# 2613     2000-07-05             US                en        Big Brother
# 2614     1997-03-31             GB                en        Teletubbies
# 2615     1985-02-19             GB                en         EastEnders
# 2616     2006-10-09             CA                fr             La Job
#
#       popularity  vote_average  vote_count  \
# 0         30.104           9.0        3071
# ...

# %%
# feature명 변경

ts_df.columns = ['date','country','language','title','popularity','vote_average','vote_count', 'overview']
ts_df
# Out:
#             date country language              title  popularity  \
# 0     2021-09-03      US       en  The D'Amelio Show      30.104
# 1     2008-01-20      US       en       Breaking Bad     468.253
# 2     2021-11-06      US       en             Arcane      95.667
# 3     2013-12-02      US       en     Rick and Morty    1511.996
# 4     2022-04-14      US       en    The Kardashians     195.038
# ...          ...     ...      ...                ...         ...
# 2612  2002-06-11      US       en      American Idol      34.052
# 2613  2000-07-05      US       en        Big Brother      47.029
# 2614  1997-03-31      GB       en        Teletubbies      36.875
# 2615  1985-02-19      GB       en         EastEnders     108.720
# 2616  2006-10-09      CA       fr             La Job       6.968
#
#       vote_average  vote_count  \
# 0              9.0        3071
# 1              8.8       10131
# 2              8.7        2615
# 3              8.7        7220
# ...

# %%
# 결측치 확인

ts_df.isna().sum()
# Out:
# date             6
# country          0
# language         0
# title            0
# popularity       0
# vote_average     0
# vote_count       0
# overview        65
# dtype: int64

# %%
# 결측치에 대한 값을 정확한 값으로 교체

# %%
# err = ts_df[ts_df.isnull().any(axis=1)]
# print(err)

# %%
# err1 = ts_df[pd.isna(ts_df['date'])]
# err1

# %%
ts_df[ts_df['title'] == 'Pandillas guerra y paz']
# Out:
#     date country language                   title  popularity  vote_average  \
# 345  NaN      CO       es  Pandillas guerra y paz       10.47           8.4
#
#      vote_count overview
# 345         152      NaN

# %%
row_index1 = ts_df[ts_df['title'] == 'Pandillas guerra y paz'].index[0]
ts_df.at[row_index1, 'date'] = '1999-09-05'

# %%
row_index2 = ts_df[ts_df['title'] == 'El Escamoso'].index[0]
ts_df.at[row_index2, 'date'] = '2001-04-19'

# %%
row_index3 = ts_df[ts_df['title'] == 'En Los Tacones De Eva'].index[0]
ts_df.at[row_index3, 'date'] = '2006-11-14'

# %%
row_index4 = ts_df[ts_df['title'] == 'Mi Coraz?n Insiste en Lola Volc?n'].index[0]
ts_df.at[row_index4, 'date'] = '2011-05-23'

# %%
row_index5 = ts_df[ts_df['title'] == 'La Mentira'].index[0]
ts_df.at[row_index5, 'date'] = '1998-07-13'

# %%
row_index6 = ts_df[ts_df['title'] == 'Para Volver a Amar'].index[0]
ts_df.at[row_index6, 'date'] = '2010-07-12'

# %%
# 결측치 모두 해결 완료

ts_df.isna().sum()
# Out:
# date             0
# country          0
# language         0
# title            0
# popularity       0
# vote_average     0
# vote_count       0
# overview        65
# dtype: int64

# %%
ts_df
# Out:
#             date country language              title  popularity  \
# 0     2021-09-03      US       en  The D'Amelio Show      30.104
# 1     2008-01-20      US       en       Breaking Bad     468.253
# 2     2021-11-06      US       en             Arcane      95.667
# 3     2013-12-02      US       en     Rick and Morty    1511.996
# 4     2022-04-14      US       en    The Kardashians     195.038
# ...          ...     ...      ...                ...         ...
# 2612  2002-06-11      US       en      American Idol      34.052
# 2613  2000-07-05      US       en        Big Brother      47.029
# 2614  1997-03-31      GB       en        Teletubbies      36.875
# 2615  1985-02-19      GB       en         EastEnders     108.720
# 2616  2006-10-09      CA       fr             La Job       6.968
#
#       vote_average  vote_count  \
# 0              9.0        3071
# 1              8.8       10131
# 2              8.7        2615
# 3              8.7        7220
# ...

# %%
ts_df.describe().T.round(2)
# Out:
#                count    mean      std    min     25%     50%     75%       max
# popularity    2617.0   59.81   222.41   0.87   16.57   27.49   49.76   6684.61
# vote_average  2617.0    7.69     0.62   0.60    7.30    7.70    8.10      9.00
# vote_count    2617.0  604.82  1223.23  99.00  150.00  257.00  569.00  19459.00

# %%
# 인덱스 수 증가

ts_df.index += 1
ts_df
# Out:
#             date country language              title  popularity  \
# 1     2021-09-03      US       en  The D'Amelio Show      30.104
# 2     2008-01-20      US       en       Breaking Bad     468.253
# 3     2021-11-06      US       en             Arcane      95.667
# 4     2013-12-02      US       en     Rick and Morty    1511.996
# 5     2022-04-14      US       en    The Kardashians     195.038
# ...          ...     ...      ...                ...         ...
# 2613  2002-06-11      US       en      American Idol      34.052
# 2614  2000-07-05      US       en        Big Brother      47.029
# 2615  1997-03-31      GB       en        Teletubbies      36.875
# 2616  1985-02-19      GB       en         EastEnders     108.720
# 2617  2006-10-09      CA       fr             La Job       6.968
#
#       vote_average  vote_count  \
# 1              9.0        3071
# 2              8.8       10131
# 3              8.7        2615
# 4              8.7        7220
# ...

# %%
# date feature의 타입을 datetime으로 변경

ts_df['date'] = pd.to_datetime(ts_df['date'])

# %%
ts_df['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# year feature 추가

ts_df['year'] = ts_df['date'].dt.year

# %%
ts_df
# Out:
#            date country language              title  popularity  vote_average  \
# 1    2021-09-03      US       en  The D'Amelio Show      30.104           9.0
# 2    2008-01-20      US       en       Breaking Bad     468.253           8.8
# 3    2021-11-06      US       en             Arcane      95.667           8.7
# 4    2013-12-02      US       en     Rick and Morty    1511.996           8.7
# 5    2022-04-14      US       en    The Kardashians     195.038           8.7
# ...         ...     ...      ...                ...         ...           ...
# 2613 2002-06-11      US       en      American Idol      34.052           5.2
# 2614 2000-07-05      US       en        Big Brother      47.029           4.9
# 2615 1997-03-31      GB       en        Teletubbies      36.875           4.1
# 2616 1985-02-19      GB       en         EastEnders     108.720           3.9
# 2617 2006-10-09      CA       fr             La Job       6.968           0.6
#
# ...

# %%
ts_df.value_counts('year')
# Out:
# year
# 2020    263
# 2021    204
# 2019    197
# 2018    163
# 2017    140
#        ...
# 1958      2
# 1968      1
# 1955      1
# 1962      1
# 1951      1
# Name: count, Length: 66, dtype: int64

# %%
ts_df['vote_average'].max()
# Out:
# 9.0

# %%
max_var = ts_df[ts_df['vote_average'] == ts_df['vote_average'].max()]
max_var
# Out:
#         date country language              title  popularity  vote_average  \
# 1 2021-09-03      US       en  The D'Amelio Show      30.104           9.0
#
#    vote_count                                           overview  year
# 1        3071  From relative obscurity and a seemingly normal...  2021

# %%
ts_df_kr = ts_df[ts_df['country'] == 'KR']
ts_df_kr
# Out:
#            date country language                            title  popularity  \
# 13   2016-12-02      KR       ko                           Goblin     138.869
# 21   2016-11-16      KR       ko  Weightlifting Fairy Kim Bok-Joo      48.446
# 22   2015-08-01      KR       ko                         Run BTS!      64.215
# 26   2016-08-29      KR       ko              Scarlet Heart: Ryeo      32.411
# 40   2021-02-20      KR       ko                         Vincenzo      36.900
# ...         ...     ...      ...                              ...         ...
# 1583 2021-11-03      KR       ko                        Dr. Brain      36.890
# 1597 2018-05-21      KR       ko                       About Time      12.577
# 1685 2021-11-19      KR       ko                        Hellbound     120.836
# 1942 2021-10-30      KR       ko                    Inspector Koo      10.512
# 2148 2016-11-16      KR       ko       The Legend of the Blue Sea      32.959
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

ts_df_sorted = ts_df.sort_values(by='vote_average', ascending=False)

sns. barplot(x='title', y='vote_average', data=ts_df_sorted.head(10))
plt.xticks(rotation=90)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

ts_df_sorted = ts_df.sort_values(by='vote_average', ascending=False)

sns. barplot(x='title', y='vote_average', data=ts_df_sorted.head(10))
plt.xticks(rotation=90)

plt.show()

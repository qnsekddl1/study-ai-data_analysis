# %% [markdown]
# ### 📋정신 건강에 대한 설문 조사 결과 데이터 분석

# %% [markdown]
# - Timestamp: 설문 제출 시간
# - Gender: 성별
# - Country: 국적
# - Job: 직업
# - Self_employed: 자영업자
# - family_history: 가족력(정신 건강 이상 여부)
# - Treatment: 치료
# - Days_Indoors: 실내 생활 일수
# - Growing_Stress: 스트레스 증가
# - Changes_Habits: 습관 변화
# - Mental_Health_History: 정신건강 이력(정신 건강 이상 여부)
# - Mood_Swings: 기분 변동폭
# - Coping_Struggles: 감정 조절 능력
# - Work_Interest: 직업 흥미 여부
# - Social_Weakness: 사회적 약자 여부
# - Mental_health_interview: 정신 건강 인터뷰 여부
# - Care_options: 치료에 대한 인식

# %%
import pandas as pd
import numpy as np

mh = pd.read_csv('./datasets/Mental Health Dataset.csv')
mh
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# 0       8/27/2014 11:29  Female  United States  Corporate           NaN
# 1       8/27/2014 11:31  Female  United States  Corporate           NaN
# 2       8/27/2014 11:32  Female  United States  Corporate           NaN
# 3       8/27/2014 11:37  Female  United States  Corporate            No
# 4       8/27/2014 11:43  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 292359  7/27/2015 23:25    Male  United States   Business           Yes
# 292360   8/17/2015 9:38    Male   South Africa   Business            No
# 292361  8/25/2015 19:59    Male  United States   Business            No
# 292362   9/26/2015 1:07    Male  United States   Business            No
# 292363   2/1/2016 23:04    Male  United States   Business            No
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# ...

# %%
mh.index += 1

# %%
# feature명 변경

mh.columns = ['Timestamp','Gender','Country','Job','Self_employed','Family_history','Treatment', 'Days_Indoors','Growing_Stress','Changes_Habits','Mental_Health_History','Mood_Swings','Coping_Struggles','Work_Interest','Social_Weakness','Mental_health_interview','Care_options']
mh
# Out:
#               Timestamp  Gender        Country        Job Self_employed  \
# 1       8/27/2014 11:29  Female  United States  Corporate           NaN
# 2       8/27/2014 11:31  Female  United States  Corporate           NaN
# 3       8/27/2014 11:32  Female  United States  Corporate           NaN
# 4       8/27/2014 11:37  Female  United States  Corporate            No
# 5       8/27/2014 11:43  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 292360  7/27/2015 23:25    Male  United States   Business           Yes
# 292361   8/17/2015 9:38    Male   South Africa   Business            No
# 292362  8/25/2015 19:59    Male  United States   Business            No
# 292363   9/26/2015 1:07    Male  United States   Business            No
# 292364   2/1/2016 23:04    Male  United States   Business            No
#
#        Family_history Treatment Days_Indoors Growing_Stress Changes_Habits  \
# ...

# %%
mh.reset_index(drop=True, inplace=True)

# %%
mh.isna().sum()
# Out:
# Timestamp                     0
# Gender                        0
# Country                       0
# Job                           0
# Self_employed              5202
# Family_history                0
# Treatment                     0
# Days_Indoors                  0
# Growing_Stress                0
# Changes_Habits                0
# Mental_Health_History         0
# Mood_Swings                   0
# Coping_Struggles              0
# Work_Interest                 0
# Social_Weakness               0
# Mental_health_interview       0
# Care_options                  0
# dtype: int64

# %%
mh.value_counts('Job')
# Out:
# Job
# Housewife    66351
# Student      61794
# Corporate    61229
# Others       52841
# Business     50149
# Name: count, dtype: int64

# %%
mh.value_counts('Self_employed')
# Out:
# Self_employed
# No     257994
# Yes     29168
# Name: count, dtype: int64

# %%
mh['Self_employed'].fillna('No', inplace=True)

# %%
mh.index += 1
mh
# Out:
#               Timestamp  Gender        Country        Job Self_employed  \
# 1       8/27/2014 11:29  Female  United States  Corporate            No
# 2       8/27/2014 11:31  Female  United States  Corporate            No
# 3       8/27/2014 11:32  Female  United States  Corporate            No
# 4       8/27/2014 11:37  Female  United States  Corporate            No
# 5       8/27/2014 11:43  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 292360  7/27/2015 23:25    Male  United States   Business           Yes
# 292361   8/17/2015 9:38    Male   South Africa   Business            No
# 292362  8/25/2015 19:59    Male  United States   Business            No
# 292363   9/26/2015 1:07    Male  United States   Business            No
# 292364   2/1/2016 23:04    Male  United States   Business            No
#
#        Family_history Treatment Days_Indoors Growing_Stress Changes_Habits  \
# ...

# %% [markdown]
# ### 🤔<span style="color: blue">스트레스</span>에 가장 큰 영향을 끼치는 것은 어떤 것일까?
# 1. 취업 여부
# 2. 성별
# 3. 외출 횟수
#
# 위 3가지가 스트레스에 어느 정도 영향을 끼치는지 각각 확인을 해보도록 하겠습니다.

# %% [markdown]
# ### 1. 취업  여부
# 취업 여부는 정신적으로나 육체적으로나 개인의 행복에 큰 영향을 미치는 것으로 알려져 있습니다.
# 그에 따라 이 부분에서는 위의 내용을 뒷받침 할 수 있는지를 확인 해볼것입니다.

# %% [markdown]
# #### 🖊️설문 조사에 참여한 인원들의 직업을 조사해보자.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.rcParams['font.family'] = 'Malgun Gothic'

plt.figure(figsize=(10, 4))
sns.countplot(x='Job', data=mh, palette = 'inferno')
plt.title('설문조사 참여 인원의 직업 분포')
plt.xlabel('직업')
plt.ylabel('')
plt.show()

# %% [markdown]
# #### 🖊️그 다음으로 각 직업의 흥미 여부를 조사 해보자.

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

plt.figure(figsize=(10, 7))
sns.countplot(x='Work_Interest', data=mh, palette = 'inferno', hue='Job')
plt.title('직업 별 직업의 흥미 여부')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# 📝 시각화 자료를 분석해보면,
# 흥미 여부 중 '그렇다' 답변이 가장 높은 직업 은 '전업 주부' 이지만, '아니다' 답변도 가장 높은 직업 또한 '전업 주부' 였다.

# %% [markdown]
# #### 🖊️그 다음으로 각 직업의 스트레스 증가 여부를 조사해보자.

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

plt.figure(figsize=(10, 7))
sns.countplot(x='Growing_Stress', data=mh, palette = 'inferno', hue='Job')
plt.title('직업 별 스트레스 증가')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# 📝 먼저 '그렇다' 가 가장 높은 직업은 '회사원' 입니다.
# 반대로 '아니다' 가 가장 높은 직업은 '전업 주부' 입니다.

# %% [markdown]
# ### 💡결론 1
# #### 위 시각화 자료들로 하여금 취업 여부 자체가 스트레스 증가에 직접적인 영향을 끼치지 않는다는 결과를 도출할 수 있습니다.

# %% [markdown]
# ### 2.성별🚹🚺
# 성별에 따른 개인의 경험과 생각의 차이는 너무나도 당연한 결과 입니다.
# 그렇다면, 성별로 인한 생각의 차이는 곧, 스트레스 증가에 대한 차이도 있을 수 있을거라 생각이 듭니다.
# 그렇기에 이 부분에서는 성별에 대한 스트레스 증가 차이를 조사해보도록 하겠습니다.

# %% [markdown]
# #### 🖊️설문 조사에 참여한 인원들의 성비를 조사해보자.

# %%
# 성별에 따른 인원 수 계산
gender_counts = mh['Gender'].value_counts()

plt.rcParams['font.family'] = 'Malgun Gothic'

colors = ['#00aaff', '#ff6347']

wedgeprops = {'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

explode = (0, 0.08)

# 원형 그래프 그리기
plt.figure(figsize=(8, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', colors=colors, wedgeprops=wedgeprops, explode=explode)
plt.title('설문조사에 참여한 인원들의 성비')
plt.axis('equal')  # 원형 그래프를 원으로 설정
plt.show()

# %% [markdown]
# 📝설문 조사에 참여한 인원들의 성비가 여성 18.0%, 남성의 비율이 82.0% 로, 약 4.5배정도 더 많습니다.
# 이로 인해 결과가 크게 왜곡되어 부정확해질 수 있습니다.

# %% [markdown]
# #### 🖊️스트레스 증가와 성별의 관계에 대해 조사해보자.

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

plt.figure(figsize=(10, 7))
sns.countplot(x='Growing_Stress', data=mh, hue='Gender',  palette = 'rocket')
plt.title('스트레스와 성별의 관계')
plt.xlabel('스트레스 증가')
plt.ylabel('')
plt.show()

# %% [markdown]
# 📝 위의 그래프는 유용한 것처럼 보이지만, 남성과 여성의 비율이 약 4.5배 차이가 나기 때문에 왜곡된 결과라고 할 수 있습니다.

# %% [markdown]
# ### 💡결론 2
# #### 이 데이터 세트에서는 남성과 여성의 공평한 비율이 아니기 때문에 정확한 분석을 진행할 수 없었습니다.

# %% [markdown]
# ### 3. 외출 횟수
# 집에서 혼자만 있는 것은 누군가에겐 황금 같은 휴식 시간일 수도 있지만, 다른 누군가에겐 고리타분한 일상일 뿐 일수도 있습니다.
# 이번에는 외출 횟수와 스트레스의 상관관계를 확인해보겠습니다.

# %% [markdown]
# #### 🖊️먼저 설문에 참여한 인원의 실내 생활수를 파악해보자.

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

plt.figure(figsize=(10, 4))
order = ['Go out Every day','1-14 days','15-30 days','31-60 days','More than 2 months']

sns.countplot(x='Days_Indoors', data=mh, palette = 'RdYlGn', order=order)
plt.title('설문조사 참여 인원의 실내 생활수')
plt.xlabel('실내 생활수')
plt.ylabel('')
plt.show()

# %% [markdown]
# #### 🖊️다음은 실내 생활수에 따른 스트레스 여부에 대해 알아보자.

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

category_order=['Go out Every day', '1-14 days', '15-30 days', '31-60 days', 'More than 2 months']
sns.catplot(x='Days_Indoors', data=mh, kind= 'count', palette = 'RdYlGn', hue='Growing_Stress', \
            order=category_order, height=7)
plt.title('실내 생활수에 따른 스트레스 여부')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# 📝 매일 외출을 하는 사람들 중 스트레스를 받는 사람보다 안받는 사람들이 더 많았습니다.
# 1-14일을 외출하지 않는 사람들 중 스트레스를 받는 사람이 안받는 사람들보다 더 많았습니다.
# 15-30일을 외출하지 않는 사람들 중 스트레스를 받는 사람이 안받는 사람들보다 더 많았습니다.
# 31-60일을 외출하지 않는 사람들은 스트레스를 받는 사람과 안받는 사람들의 수가 비슷했습니다.
# 2달 이상을 외출하지 않는 사람들 중 스트레스를 받는 사람의 수가 안받는 사람들보다 더 많았습니다.
#
# 이는 스트레스를 해소할 수 있는 방법은 매일매일 잠깐이라도 외출을 하는것임을 알 수 있습니다.

# %% [markdown]
# ### 💡결론 3
# #### 위 시각화 그래프를 통해서 외출 횟수가 스트레스에 큰 영향을 준다는 것을 알 수 있습니다.

# %% [markdown]
# # 📋요약
#
# 1. 취업 여부
# 취업 여부는 스트레스와 상관관계가 크지 않다고 보입니다.
# 그 이유는 직업별 스트레스 증가의 응답인 'Yes' 가 가장 높은 그룹이 '회사원' 이기 때문입니다.
# 그에 반면 뚜렷한 직장이 없거나 무직인 '전업주부' 들의 스트레스 증가의 응답인 'NO' 가 가장 높기 때문이기도 합니다.
#
# 2. 성별
# 이 설문조사에선 남성의 비율이 여성의 비율보다 4.5배 정도 많았기 때문에 공정하고 객관적인 분석을 할 수 없었습니다.
# 하지만 성별에 대한 스트레스 수준을 분석 해본다는 것은 아주 흥미로운 주제라고 생각합니다.
# (관련 데이터 세트를 더 찾아봤지만 찾을 수 없어서 분석을 진행하지 못하였습니다. 추후 관련 데이터를 찾아 분석을 진행 해보고 싶습니다.)
#
# 3. 외출 횟수
# 외출 횟수는 스트레스 수준에 큰 영향을 미칩니다.
# 매일매일 잠깐이라도 외출을 하는 것이 오랫동안 외출을 하지 않는 것보다 스트레스 완화에 큰 도움이 됩니다.
